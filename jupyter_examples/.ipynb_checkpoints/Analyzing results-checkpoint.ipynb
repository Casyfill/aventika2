# %%
import pandas as pd
import geopandas as gp
import qgrid
from palettable.tableau import Tableau_20

# %%
# %matplotlib inline
from matplotlib import pylab as plt

# %% [markdown]
# # READING DATA

# %%
offices = pd.read_csv('../data/results/2017_01_05_23_10_56_reg01_office_results.csv')
atms    = pd.read_csv('../data/results/2017_01_06_10_37_29_reg01_atm_results.csv') 

results = pd.concat([atms, offices])

# %%
results.head(2)
# Out:
#                                               f_pois  \
# 0  508|837|943|31|4693|4717|4501|4904|4869|4900|4...
# 1  4267|3805|3785|3806|3784|3807|3783|4247|4260|4...
#
#                                               s_pois  reg_score  priority  \
# 0  508|837|943|4693|4717|4501|4904|4869|4900|4830...      632.2         1
# 1               4247|4260|4266|9585|9586|11798|11799     2934.2         2
#
#    office_id   score
# 0       2060  3635.2
# 1       1271  3489.2

# %%
results.loc[pd.notnull(results['f_pois']), 'f_pois']  =  results.loc[pd.notnull(results['f_pois']), 'f_pois'].apply(lambda x: [int(y) for y in x.split('|')])
results.loc[pd.notnull(results['s_pois']), 's_pois']  =  results.loc[pd.notnull(results['s_pois']), 's_pois'].apply(lambda x: [int(y) for y in x.split('|')])

# %%
results.loc[ pd.isnull(results[['f_pois', 's_pois']]).any(1), ['f_pois', 's_pois']] = None

# %%
def tol_joiner(x, y):

    if x is None or isinstance(x, str):
        x = []
    if y is None or isinstance(y, str):
        y = []
    
    return x + y

# %%
results['pois'] = results.apply(lambda x: tol_joiner(x['f_pois'], x['s_pois']),1)

# %%
results.drop(['s_pois', 'f_pois'], axis=1, inplace=1)

# %%
banks = gp.read_file('data/real/raw/banks.geojson')[['name', 'address', 'shop_intersect','type', 'office_id']]

# %%
banks = banks.merge(results, on='office_id', how='left')
banks['score'].fillna(0, inplace=1)

# %%
banks
# Out:
#                       name                                            address  \
# 0            ВСП 7954/1110                                 г. Зеленоград, 315
# 1            ВСП 7954/1559                               г. Зеленоград, 1561Б
# 2     Доп.офис №9038/01150                         г.Москва, ул.Смольная, д.7
# 3      Доп.офис №9038/0518                      г.Москва, ул.Первомайская, 42
# 4        Банкомат 11108742                         г. Москва,Улица Снежная 26
# 5          Банкомат 381563                   г. Москва,Улица Садовническая 33
# 6                   193651                          г. Москва,Улица 8 Марта 6
# 7          Банкомат 650142                         г. Москва,Улица Малышева 3
# 8          Банкомат 688711                            г. Мамыри,   41 Км Мкад
# 9          Банкомат 830351                     г. Москва,Проспект Рязанский 2
# 10         Банкомат 689787                         г. Москва,Улица Снежная 27
# 11         Банкомат 101457                      г. Москва,Дорога Мкад 87 Км 8
# 12         Банкомат 830267                        г. Москва,Улица Ратная 16 2
# 13       Банкомат 10155466                          г. Москва,Бульвар Осенний
# 14         Банкомат 975692                    г. Москва,Шоссе Каширское 142 1
# 15         Банкомат 830206                      г. Москва,Улица Ярцевская 25а
# 16         Банкомат 321797                      г. Москва,Улица ГАРИБАЛЬДИ 23
# 17      Офис СО №9038/9033                   г. Москва, Чонгарский бульвар, 5
# 18    Доп.офис №9038/01749                    г.Москва, Ореховый бульвар, 22А
# 19         Банкомат 830538                                г. Зеленоград, 1627
# 20         Банкомат 984578                      г. Москва,Проспект Мира 211 1
# 21    Доп.офис №9038/01251                        г.Москва, ул.Уссурийская, 5
# 22     Доп.офис №9038/0823                       г. Москва, ул. Лосевская, 22
# 23         Банкомат 907284                         г. Москва,Улица Елецкая 14
# 24         Банкомат 890221                       г. Москва,Улица Митинская 56
# 25                  158689                         г. Москва,Проспект Мира 97
# 26       Банкомат 10983239            г. Москва,Улица Бакунинская 7строение 1
# 27         Банкомат 890157                        г. Москва,Улица Поречная 10
# 28       Банкомат 11013333              г. Москва,Улица Космонавта Волкова 12
# 29       Банкомат 10085960               г. Москва,Проспект МАРШАЛА ЖУКОВА 44
# ...                    ...                                                ...
# 2361     Доп.офис №9038/01                  г.Москва, Зеленоград, корпус 834а
# 2362     Доп.офис №9038/01                   г.Москва, Зеленоград, корпус 601
# 2363     Доп.офис №9038/01                   г.Москва, Зеленоград, корпус 445
# 2364     Доп.офис №9038/01                  г.Москва, г.Зеленоград, корп. 315
# 2365     Доп.офис №9038/01                  г.Москва, Зеленоград, корпус 1106
# 2366     Доп.офис №9038/01           г.Москва, Щелковское шоссе, 79, корпус 1
# 2367     Доп.офис №9038/01                г.Москва, Преображенская площадь, 8
# 2368     Доп.офис №9038/01   г.Москва, Милютинский переулок, 19/4, строение 2
# 2369     Доп.офис №9038/01              г.Москва, ул. Большая Семеновская, 28
# 2370     Доп.офис №9038/01            г.Москва, ул.Люсиновская 70, строение 1
# 2371     Доп.офис №9038/01             г.Москва, ул.Пятницкая, 74, строение 5
# 2372     Доп.офис №9038/01                      г.Москва, ул. Люблинская, 157
# 2373     Доп.офис №9038/01                        г.Москва, ул.Люблинская, 38
# 2374     Доп.офис №9038/01           г.Москва, ул.Кировоградская, 8, корпус 3
# 2375     Доп.офис №9038/01                          г.Москва, ул.Горбунова, 2
# 2376     Доп.офис №9038/01                      г. Москва, ул. Енисейская, 29
# 2377     Доп.офис №9038/01                        г. Москва, ул. Сретенка, 14
# 2378     Доп.офис №9038/01           г.Москва, ул.Баррикадная, 19, строение 1
# 2379     Доп.офис №9038/01         г.Москва, ул.Старокачаловская, 1, корпус 1
# 2380     Доп.офис №9038/01           г.Москва, ул. Сретенка, 17, строение 1-2
# 2381     Доп.офис №9038/01                   г.Москва, ул.Кировоградская, 23А
# 2382     Доп.офис №9038/01             г.Москва, ул. Шарикоподшипниковская, 2
# 2383     Доп.офис №9038/01   г.Москва, ул.Новокузнецкая, 16-18/10, строение 3
# 2384     Доп.офис №9038/01                     г.Москва, ул.Краснодонская, 12
# 2385     Доп.офис №9038/01  г.Москва, Наставнический переулок, д.17, строе...
# 2386     Доп.офис №9038/01                         г.Москва, ул.Мясницкая, 17
# 2387     Доп.офис №9038/01   г.Москва, Ипатьевский переулок, 4/10, строение 1
# 2388     Доп.офис №9038/01                 г.Москва, г.Зеленоград, корпус 249
# 2389     Доп.офис №9038/01                  г.Москва, Зеленоград, корпус 435а
# 2390     Доп.офис №9038/01     г.Москва, Ленинградский проспект, 76, корпус 2
#
#      shop_intersect                        type  office_id  reg_score  \
# 0                                     Отделение       2378      201.1
# 1                                     Отделение       2387      128.7
# 2                                     Отделение        230      362.5
# 3              true                   Отделение        367      185.8
# 4                                      Банкомат        906      367.9
# 5                                      Банкомат       1096      258.3
# 6                    Отделение самообслуживания       1591      407.9
# 7                                      Банкомат       1732      487.4
# 8              true                    Банкомат        896        0.1
# 9                                      Банкомат        978       66.4
# 10             true                    Банкомат       2075      397.7
# 11                                     Банкомат       2200      434.5
# 12                                     Банкомат       2273       66.2
# 13                                     Банкомат         59      137.8
# 14                                     Банкомат       1318      300.1
# 15             true                    Банкомат       1892       72.3
# 16             true                    Банкомат       2163      359.2
# 17                                    Отделение        142      285.8
# 18             true                   Отделение        479      466.9
# 19                                     Банкомат        873      213.7
# 20             true                    Банкомат       1055      123.2
# 21                                    Отделение        325      332.5
# 22                                    Отделение        565      220.9
# 23                                     Банкомат       1045     1462.1
# 24             true                    Банкомат       1312      424.8
# 25                   Отделение самообслуживания       1565      142.2
# 26                                     Банкомат          1      284.0
# 27             true                    Банкомат          2      458.2
# 28                                     Банкомат          3      196.8
# 29                                     Банкомат          4      179.5
# ...             ...                         ...        ...        ...
# 2361                                  Отделение        302      126.3
# 2362                                  Отделение        301      139.6
# 2363                                  Отделение        300      203.3
# 2364                                  Отделение        298      198.9
# 2365                                  Отделение        297      119.2
# 2366                                  Отделение        350      387.4
# 2367                                  Отделение        349      299.9
# 2368                                  Отделение        339      288.7
# 2369                                  Отделение        352      224.0
# 2370                                  Отделение        401      144.3
# 2371                                  Отделение        420      254.1
# 2372                                  Отделение        418      532.2
# 2373                                  Отделение        416      199.4
# 2374                                  Отделение        481      269.5
# 2375                                  Отделение        581      108.7
# 2376                                  Отделение        543      486.6
# 2377                                  Отделение        528      242.0
# 2378                                  Отделение        751      190.9
# 2379                                  Отделение        482      137.1
# 2380                                  Отделение        540      237.6
# 2381                                  Отделение        450      331.2
# 2382                                  Отделение        421      226.9
# 2383                                  Отделение        407      253.9
# 2384                                  Отделение        381      223.9
# 2385                                  Отделение        353       84.1
# 2386                                  Отделение        351      257.0
# 2387                                  Отделение        345      180.2
# 2388                                  Отделение        312      197.0
# 2389                                  Отделение        299      228.8
# 2390                                  Отделение        273      289.9
#
#       priority   score                                               pois
# 0        369.0   606.1  [10191, 10190, 10192, 10193, 670, 10189, 10188...
# 1        515.0   388.7  [10266, 10267, 10268, 10269, 10270, 10271, 102...
# 2        175.0  1057.5  [554, 555, 1247, 1264, 1266, 1244, 1265, 1245,...
# 3         23.0  2140.8  [56, 757, 843, 733, 4186, 4161, 4185, 4162, 41...
# 4        659.0   387.9                                                 []
# 5        141.0  1248.3  [284, 277, 278, 5397, 5404, 5405, 5577, 6542, ...
# 6        499.0   407.9                                                 []
# 7        532.0   487.4                                                 []
# 8       1452.0     0.1                                                 []
# 9        473.0   551.4  [750, 5279, 5296, 5278, 5583, 5567, 5566, 5466...
# 10        17.0  2637.7  [257, 251, 242, 210, 903, 3668, 237, 2013, 201...
# 11       600.0   434.5                                                 []
# 12      1250.0   111.2                                       [8817, 9889]
# 13       329.0   747.8  [2667, 2475, 2469, 2476, 2486, 2668, 2484, 247...
# 14       431.0   595.1  [6951, 6952, 6987, 6528, 6529, 7163, 6988, 716...
# 15      1342.0    72.3                                                 []
# 16       710.0   359.2                                                 []
# 17       545.0   355.8                                 [8227, 3628, 3667]
# 18        90.0  1501.9  [121, 570, 6610, 6640, 6611, 6639, 7225, 7258,...
# 19       502.0   523.7  [10272, 10273, 10274, 10275, 10279, 10281, 102...
# 20       734.0   343.2  [9158, 3171, 2563, 3866, 3860, 3859, 9158, 106...
# 21       327.0   682.5  [4521, 4522, 4535, 4536, 4541, 4542, 4557, 468...
# 22       329.0   680.9  [129, 2009, 2595, 2571, 2594, 2572, 3400, 3405...
# 23        52.0  1912.1  [570, 6788, 6782, 7225, 7258, 7293, 117, 6788,...
# 24        20.0  2494.8  [653, 964, 790, 8458, 8457, 8460, 8459, 8462, ...
# 25       829.0   142.2                                                 []
# 26       761.0   328.0                                                 []
# 27       476.0   548.2                           [8756, 8502, 9389, 9388]
# 28       851.0   276.8                                                 []
# 29       785.0   314.5             [1696, 8280, 11658, 1696, 8280, 11658]
# ...        ...     ...                                                ...
# 2361     151.0  1151.3  [559, 10175, 1038, 701, 10151, 10150, 10172, 1...
# 2362     391.0   570.6  [666, 667, 10161, 10198, 10208, 10160, 10197, ...
# 2363     672.0   253.3                                                 []
# 2364     747.0   198.9                                                 []
# 2365     803.0   164.2                                     [10315, 10316]
# 2366     377.0   587.4  [4434, 4616, 8291, 11193, 11192, 4434, 4616, 8...
# 2367     494.0   414.9                     [4290, 6044, 4290, 6044, 8261]
# 2368     615.0   313.7                                                 []
# 2369     716.0   224.0                                                 []
# 2370     823.0   144.3                                                 []
# 2371     299.0   749.1  [3646, 3647, 3657, 3648, 3656, 3649, 3655, 631...
# 2372      34.0  1917.2  [502, 95, 8747, 8507, 8506, 8482, 8324, 8746, ...
# 2373     409.0   539.4  [102, 5222, 5223, 6005, 5892, 7930, 5222, 5221...
# 2374     558.0   344.5                                                 []
# 2375     766.0   193.7                           [2810, 2710, 6042, 2710]
# 2376     388.0   571.6                       [10793, 10795, 11791, 10793]
# 2377      80.0  1578.0  [269, 256, 297, 690, 852, 3710, 6230, 6231, 64...
# 2378     312.0   720.9  [1513, 1947, 1954, 2547, 2548, 5387, 6313, 632...
# 2379     810.0   157.1                                                 []
# 2380     701.0   237.6                                                 []
# 2381     390.0   571.2  [3355, 3362, 3354, 3363, 3353, 3364, 8115, 335...
# 2382     350.0   636.9  [215, 4240, 4244, 6182, 6186, 6783, 7008, 7009...
# 2383     549.0   353.9                                                 []
# 2384     412.0   533.9  [6057, 6147, 6142, 6141, 6148, 6052, 6056, 605...
# 2385     471.0   444.1  [4507, 6213, 8192, 8190, 9404, 9405, 10599, 11...
# 2386     356.0   627.0  [290, 3709, 7482, 7483, 7481, 9679, 9680, 1184...
# 2387     715.0   225.2                                      [5573, 11357]
# 2388     753.0   197.0                                                 []
# 2389     712.0   228.8                                                 []
# 2390     632.0   289.9                                                 []
#
# [2391 rows x 9 columns]

# %%
len(results[pd.notnull(results['priority'])])
# Out:
# 2365

# %%
banks[pd.isnull(banks['priority'])]
# Out:
#                    name                                            address  \
# 98      Банкомат 184296                                      г. ЛАПШИНКА,8
# 636   Доп.офис №9038/01                      г.Москва, с. Красная Пахра 10
# 821     Банкомат 693903                    г. Ж/К ДУБРОВКАУлица Сосновая 6
# 842     Банкомат 650014                г. Зеленоград, Площадь Крюковская 1
# 849     Банкомат 650261                                    г. КАРТМАЗОВО,7
# 850     Банкомат 248717                                    г. КАРТМАЗОВО,7
# 1249  Банкомат 10095083          г. Москва,Километр Новорижское Шоссе 22-й
# 1250  Банкомат 10095082          г. Москва,Километр Новорижское Шоссе 22-й
# 1251  Банкомат 10095084          г. Москва,Километр Новорижское Шоссе 22-й
# 1313    Банкомат 252219                     г. Москва,Шоссе Иваньковское 3
# 1703    Банкомат 992092  г. Москва,Километр Киевское шоссе 22-й (п Моск...
# 2129    Банкомат 650245  г. Москва,Километр Калужское шоссе 22-й (п Сос...
# 2130    Банкомат 439267  г. Москва,Километр Калужское шоссе 22-й (п Сос...
# 2131    Банкомат 830390  г. Москва,Километр Калужское шоссе 22-й (п Сос...
# 2269    Банкомат 780250                   г. Москва,Шоссе Шереметьевское 9
# 2285    Банкомат 802148                    г. Московский,Улица Солнечная 3
# 2286    Банкомат 802149                    г. Московский,Улица Солнечная 3
# 2287    Банкомат 688697                                  г. РАССКАЗОВКА200
# 2291    Банкомат 688695                         г. Троицк,Улица Радужная 2
# 2299    Банкомат 287850  Поселок Воскресенское  владение   Ок Архангель...
# 2301    Банкомат 688717                                  Поселок Крекшино2
# 2302    Банкомат 850613             Поселок ЛМСМикрорайон Солнечный г.ок 1
# 2303    Банкомат 890223                   Поселок РоговоУлица Юбилейная 1А
# 2306    Банкомат 688687                      Рабочий поселок Киевский  18б
# 2324   Банкомат 2014364  Поселок Марушкинское   Индустриальный Парк (вн...
# 2336  Доп.офис №9038/01                         г.Москва, пос. Кленово, 10
#
#      shop_intersect       type  office_id  reg_score  priority  score pois
# 98                    Банкомат        894        NaN       NaN    0.0  NaN
# 636                  Отделение        653        NaN       NaN    0.0  NaN
# 821                   Банкомат        861        NaN       NaN    0.0  NaN
# 842                   Банкомат        884        NaN       NaN    0.0  NaN
# 849                   Банкомат        891        NaN       NaN    0.0  NaN
# 850                   Банкомат        892        NaN       NaN    0.0  NaN
# 1249                  Банкомат       1302        NaN       NaN    0.0  NaN
# 1250                  Банкомат       1303        NaN       NaN    0.0  NaN
# 1251                  Банкомат       1304        NaN       NaN    0.0  NaN
# 1313                  Банкомат       1368        NaN       NaN    0.0  NaN
# 1703                  Банкомат       1761        NaN       NaN    0.0  NaN
# 2129           true   Банкомат       2194        NaN       NaN    0.0  NaN
# 2130           true   Банкомат       2195        NaN       NaN    0.0  NaN
# 2131           true   Банкомат       2196        NaN       NaN    0.0  NaN
# 2269                  Банкомат       2336        NaN       NaN    0.0  NaN
# 2285                  Банкомат       2352        NaN       NaN    0.0  NaN
# 2286           true   Банкомат       2353        NaN       NaN    0.0  NaN
# 2287                  Банкомат       2354        NaN       NaN    0.0  NaN
# 2291                  Банкомат       2358        NaN       NaN    0.0  NaN
# 2299                  Банкомат       2368        NaN       NaN    0.0  NaN
# 2301                  Банкомат       2370        NaN       NaN    0.0  NaN
# 2302                  Банкомат       2371        NaN       NaN    0.0  NaN
# 2303                  Банкомат       2373        NaN       NaN    0.0  NaN
# 2306                  Банкомат       2376        NaN       NaN    0.0  NaN
# 2324           true   Банкомат       2372        NaN       NaN    0.0  NaN
# 2336                 Отделение        650        NaN       NaN    0.0  NaN

# %%
results[pd.notnull(results['priority'])].sort_values('priority').head(10)
# Out:
#    reg_score  priority  office_id   score  \
# 0      632.2         1       2060  3635.2
# 0     2484.3         1        399  3986.3
# 1     2842.3         2        627  3760.3
# 1     2934.2         2       1271  3489.2
# 2     1486.9         3       1938  3356.9
# 2     3173.8         3        329  3641.8
# 3      270.2         4       2267  3333.2
# 3     1146.9         4        848  3584.9
# 4      221.3         5       2086  3216.3
# 4     1663.5         5        778  3366.5
#
#                                                 pois
# 0  [508, 837, 943, 31, 4693, 4717, 4501, 4904, 48...
# 0  [106, 108, 855, 947, 6036, 8318, 8312, 8319, 8...
# 1  [571, 641, 647, 8132, 8583, 8527, 8526, 8582, ...
# 1  [4267, 3805, 3785, 3806, 3784, 3807, 3783, 424...
# 2  [855, 947, 8311, 8320, 8486, 8511, 8483, 8315,...
# 2  [32, 25, 4825, 4818, 5005, 5006, 5007, 5010, 5...
# 3  [82, 78, 84, 787, 6722, 74, 743, 857, 926, 86,...
# 3  [82, 787, 6722, 743, 857, 78, 74, 974, 6724, 6...
# 4  [784, 879, 907, 924, 753, 1861, 1866, 1875, 11...
# 4  [892, 962, 887, 650, 8465, 8475, 8453, 8454, 8...

# %% [markdown]
# ### SCORE/USE Histogram

# %%
banks['type'].value_counts()
# Out:
# Банкомат                      1480
# Отделение                      744
# Отделение самообслуживания     167
# Name: type, dtype: int64

# %%
results['score'].sort_values(ascending=False).reset_index(drop=True).plot(kind='area', stacked=False, color='teal',figsize=(16,10))
plt.xlabel('Bank offices, sorted')
plt.ylabel('Score')
plt.title('Distribution of scores, sorted')

# %%
fig, axes = plt.subplots(2,1, figsize=(18,12))

banks.loc[banks['type']!=u'Банкомат', 'score'].sort_values(ascending=False).reset_index(drop=True).plot(kind='area', stacked=False, color='teal',ax=axes[0])
banks.loc[banks['type']==u'Банкомат', 'score'].sort_values(ascending=False).reset_index(drop=True).plot(kind='area', stacked=False, color='black',ax=axes[1])
axes[0].set_title('Offices')
axes[1].set_title('ATMs')

# %%
fig, ax = plt.subplots(figsize=(12,12))

office_score = banks.loc[banks['type']!=u'Банкомат', 'score'].fillna(0)
atm_score = banks.loc[banks['type']==u'Банкомат', 'score'].fillna(0)

colors = ('teal', 'red')
for color, el, name in zip(colors, (office_score, atm_score), ('Office', 'ATM')):
    el = 100*el.sort_values(ascending=False).reset_index(drop=True).cumsum()/el.sum()
    el.index = 100.*el.index/len(el)
    el.plot(kind='area', stacked=False ,ax=ax, color=color, alpha=.2, label=name)
    
    ix = el[el>=50].index[0] # first object above 50% of total
    plt.vlines(ix, 0, 100, colors=color, label='50% of {}'.format(name))
    print("{} first {}s will cover more than 50% of potential demand".format(int(ix*len(el)/100),name))
    


plt.hlines(50, 0, 100, colors='b', label='50%')

plt.xlabel('Bank offices, descending by priority')
plt.plot([[0,100],[0,2300]])
plt.ylabel('Total score, %')
plt.title('ROC, Distribution of scores')
plt.legend()
# Out:
# 190 first Offices will cover more than 50% of potential demand
# 260 first ATMs will cover more than 50% of potential demand

# %% [markdown]
# ## Distribution of scores

# %%
pois = gp.read_file('data/poi.geojson', encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-87-cedc50384913> in <module>()
# ----> 1 pois = gp.read_file('../data/clean_data/poi.geojson', encoding="utf-8")
#
# /Users/casy/anaconda/lib/python2.7/site-packages/geopandas/io/file.pyc in read_file(filename, **kwargs)
#      19     """
#      20     bbox = kwargs.pop('bbox', None)
# ---> 21     with fiona.open(filename, **kwargs) as f:
#      22         crs = f.crs
#      23         if bbox is not None:
#
# /Users/casy/anaconda/lib/python2.7/site-packages/fiona/__init__.pyc in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     163                 raise IOError("no such archive file: %r" % archive)
#     164         elif path != '-' and not os.path.exists(path):
# --> 165             raise IOError("no such file or directory: %r" % path)
#     166         c = Collection(path, mode, driver=driver, encoding=encoding,
#     167                        layer=layer, vsi=vsi, archive=archive,
#
# IOError: no such file or directory: '../data/clean_data/poi.geojson'

# %%
pois['score'] = pois['score'].astype(float)

# %%
pois['score'].sort_values(ascending=False).reset_index(drop=True).plot(kind='area', stacked=False, color='teal',figsize=(12,12))
plt.title("Distribution of scores amoung POI's")
plt.xlabel('Pois, sorted decending')
plt.ylabel('Score')

# %%
pois[['score','group']].groupby('group').agg(['sum', 'count','mean'])
# Out:
#                                                         score         \
#                                                           sum  count
# group
# TC                                                   58500.00    195
# transport                                           294250.00  10958
# Больницы                                              1665.00    147
# ВОИ                                                   1450.00     26
# Дома престарелых                                       400.00     16
# Культурные мероприятия для инвалидов                     0.25      1
# НКО                                                   5601.50    107
# Образовательные учреждения с квотами для инвалидов   13200.00    124
# Работодатели инвалидов                                5925.00     29
# Ресурсные центры                                      4275.00     32
# Специальные объекты культуры для инвалидов            2000.00     27
# Спорт                                                 2010.75    101
# Центры реабилитации                                  10100.00     44
# Центры социального обслуживания                      12400.00     63
#
#
#                                                           mean
# group
# TC                                                  300.000000
# transport                                            26.852528
# Больницы                                             11.326531
# ВОИ                                                  55.769231
# Дома престарелых                                     25.000000
# Культурные мероприятия для инвалидов                  0.250000
# НКО                                                  52.350467
# Образовательные учреждения с квотами для инвалидов  106.451613
# Работодатели инвалидов                              204.310345
# Ресурсные центры                                    133.593750
# Специальные объекты культуры для инвалидов           74.074074
# Спорт                                                19.908416
# Центры реабилитации                                 229.545455
# Центры социального обслуживания                     196.825397

# %%
print pois['score'].sum()
print pois['score'].count()
print pois['score'].mean()
# Out:
# 411777.5
# 11870
# 34.6906065712

# %%
pois[['score','subgroup']].groupby('subgroup').agg(['sum', 'count','mean'])
# Out:
#                                                        score         \
#                                                          sum  count
# subgroup
# mcc                                                   4650.0     31
# stops                                               270200.0  10808
# subway                                               10000.0     25
# train                                                 9400.0     94
# АНО                                                    100.0      3
# БФ                                                     177.5      5
# Библиотеки                                             300.0      8
# ВОГ                                                   2407.5     51
# ВОГ, главное отделение                                 300.0      1
# ВОИ                                                   1250.0     25
# ВОИ, Главное отделение                                 500.0      2
# ВОС                                                   1150.0     23
# ВОС, Главное отделение                                 300.0      1
# ВУЗЫ                                                   555.0     14
# Городские больницы                                     225.0      3
# Детские площадки                                        50.0      1
# Дневные стационары                                    1440.0    144
# Дома престарелых                                       400.0     16
# Кино                                                   100.0      2
# Клуб                                                   895.0     16
# Колледжи                                               500.0     10
# Мастер-классы                                           75.0      1
# Мастерские                                            5925.0     29
# НКО                                                    900.0     20
# Общежитие ВУЗа                                          75.0      1
# Объединение                                            100.0      1
# Одежда и обувь для детей с ограничением по здор...      45.0      3
# Пункты выдачи и пункты проката технических сред...    4200.0     28
# РОО                                                    256.5     11
# Развивающие центры                                    7100.0     35
# Разовые мероприятия                                      1.0      4
# Ресурсные центры                                        30.0      1
# Спорт                                                 1620.0     88
# Танцы                                                   50.0      1
# Театр                                                  400.0      4
# Торговый центр                                       58500.0    195
# Училище                                                600.0      6
# Центр ремесел                                          200.0      1
# Центры социального обслуживания                      12400.0     63
# Центры социальной реабилитации                        3000.0      9
# Школы общеобразовательные для детей с ограничен...    5800.0     58
# Школы-интернаты                                       5600.0     28
#
#
#                                                           mean
# subgroup
# mcc                                                 150.000000
# stops                                                25.000000
# subway                                              400.000000
# train                                               100.000000
# АНО                                                  33.333333
# БФ                                                   35.500000
# Библиотеки                                           37.500000
# ВОГ                                                  47.205882
# ВОГ, главное отделение                              300.000000
# ВОИ                                                  50.000000
# ВОИ, Главное отделение                              250.000000
# ВОС                                                  50.000000
# ВОС, Главное отделение                              300.000000
# ВУЗЫ                                                 39.642857
# Городские больницы                                   75.000000
# Детские площадки                                     50.000000
# Дневные стационары                                   10.000000
# Дома престарелых                                     25.000000
# Кино                                                 50.000000
# Клуб                                                 55.937500
# Колледжи                                             50.000000
# Мастер-классы                                        75.000000
# Мастерские                                          204.310345
# НКО                                                  45.000000
# Общежитие ВУЗа                                       75.000000
# Объединение                                         100.000000
# Одежда и обувь для детей с ограничением по здор...   15.000000
# Пункты выдачи и пункты проката технических сред...  150.000000
# РОО                                                  23.318182
# Развивающие центры                                  202.857143
# Разовые мероприятия                                   0.250000
# Ресурсные центры                                     30.000000
# Спорт                                                18.409091
# Танцы                                                50.000000
# Театр                                               100.000000
# Торговый центр                                      300.000000
# Училище                                             100.000000
# Центр ремесел                                       200.000000
# Центры социального обслуживания                     196.825397
# Центры социальной реабилитации                      333.333333
# Школы общеобразовательные для детей с ограничен...  100.000000
# Школы-интернаты                                     200.000000

# %% [markdown]
# ## Contribution to first 20

# %%
z = reduce(lambda x,y: x+y, results.sort_values('score', ascending=False).head(20)['pois'].tolist())

# %%
pois20 = pois[pois.pid.isin(z)]
pois20.shape
# Out:
# (0, 12)

# %%
pp = banks.sort_values('score', ascending=False).head(20)
pp = pp[['office_id', 'pois']].set_index('office_id').to_dict()['pois']

# %%
r = {}
for key in pp:
    for x in pp[key]:
        r[int(x)] = key
r = pd.Series(r)

# %%
#pois.set_index('pid', inplace=1)
pois['office_id'] = r

# %%
pois.head(2)
# Out:
#                                              address disability  \
# 0  109451, Москва, Перервинский бульвар, дом 5, к...    general
# 1                109387, г. Москва, ул. Тихая, д. 23       deaf
#
#                       geometry     group   id importance  \
# 0  POINT (37.765169 55.662807)  Больницы   75        1.0
# 1  POINT (37.741669 55.686033)       НКО  101        2.0
#
#                                     name  pid pop  score            subgroup  \
# 0  ГБУЗ Онкологический диспансер № 5 ДЗМ   76  10   10.0  Дневные стационары
# 1              МГО ВОГ Местное отделение  102  25   50.0                 ВОГ
#
#    office_id
# 0        NaN
# 1        NaN

# %%
contribution = pois[pd.notnull(pois['office_id'])].groupby(['office_id', 'group']).agg({'score':sum}).unstack().fillna(0)

# %%
c_summ = contribution.sum(1)

# %%
c_summ.sort_values(ascending=False)
# Out:
# office_id
# 2267.0    1200.00
# 2085.0    1075.00
# 1859.0     985.00
# 1512.0     935.00
# 1535.0     885.00
# 2030.0     860.00
# 367.0      800.00
# 1511.0     785.00
# 2060.0     760.00
# 2014.0     740.00
# 1144.0     676.50
# 2171.0     660.00
# 675.0      655.00
# 124.0      650.00
# 2062.0     575.00
# 2161.0     525.00
# 1312.0     485.00
# 299.0      485.00
# 1896.0     295.00
# 1521.0     210.25
# dtype: float64

# %%
contribution['total'] = contribution.sum(1)

# %%
contribution.columns = contribution.columns.get_level_values(1)

# %%
contribution.columns
# Out:
# Index([u'TC', u'transport', u'Больницы', u'ВОИ', u'Дома престарелых',
#        u'Культурные мероприятия для инвалидов', u'НКО',
#        u'Образовательные учреждения с квотами для инвалидов',
#        u'Ресурсные центры', u'Специальные объекты культуры для инвалидов',
#        u'Спорт', u'Центры реабилитации', u'Центры социального обслуживания'],
#       dtype='object', name=u'group')

# %%
contribution.columns = ['TC', 'transport', 'hospital', 'VOI',
                        'Elderly','Cultural events','NCO', 'Education', 
                       'Resource_services','Cutural objects', 'Sport', 
                        'Reabilitation', 'Social service', 'total']

# %%
contribution.sort_values('total', ascending=0)[[x for x in contribution.columns if x != 'total']].plot(kind='bar', color=Tableau_20.mpl_colors
, stacked=1, figsize=(18,10))
plt.ylabel('score')
plt.title('Contribution of score to top 20 offices')
