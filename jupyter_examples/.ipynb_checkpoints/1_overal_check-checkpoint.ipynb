# %%
# %pylab inline
import pylab as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import geopandas as gp
from datetime import datetime

from code.main import getSettings, data_preload
from code.misc.logger import getLogger
from code.misc import getRegScore

# %%
from code.iteration import iteration, iterate

# %%
idx = pd.IndexSlice

# %% [markdown]
# # LOAD DATA

# %%
settings = getSettings()

# %%
start = datetime.now()  # start of the calculations

settings['limit'] = None
settings['logger'] = getLogger()
result_path = datetime.now().strftime(start.strftime(settings['results']))

# %%
poi, buff, reg = data_preload(settings)

# %% [markdown]
# ## Check Visually

# %%
ax = reg.plot(alpha=.1)
buff.plot(alpha=.2, ax=ax)
poi.plot(ax=ax)

plt.axis('off');

# %%
def get_overlay(buff, reg):
    '''transforms regions into set of non-covered
    elements. for each we get a centroid and assigned
    score
    
    Args:
        buff:buffer
        reg: regions
        
    Returns:
        points geodataframe
    '''
    z = gp.overlay(buff, reg,'union')
    z = z[pd.notnull(z['reg_id'])]
    z['score'] = z['disabled'] * z.area / z['reg_area']
    z['geometry'] = z.centroid
    return z[['reg_id', 'geometry', 'score']]


regs_overlayed = get_overlay(buff, reg)

# %%
r3 = z[z['reg_id']==3.0]
len(r3)
# Out:
# 13

# %%
z[z['reg_id']==3.0].plot()

# %%
z[z['reg_id']==3.0]
# Out:
#     disabled                                           geometry    id  \
# 0      800.0  POLYGON ((323507.9620164297 6177909.451193769,...     2
# 1      800.0  POLYGON ((323483.4274752385 6177912.592305607,...     2
# 4      800.0  POLYGON ((323434.0749130016 6177906.029970239,...     2
# 5      800.0  POLYGON ((324055.2331559643 6177903.750400729,...  None
# 35     800.0  POLYGON ((322569.6944128273 6177413.595974888,...     0
# 36     800.0  POLYGON ((322875.3326150714 6177803.038993755,...  None
# 37     800.0  POLYGON ((322875.3326150714 6177803.038993755,...     0
# 38     800.0  POLYGON ((322950.9591454403 6177841.030235771,...     2
# 40     800.0  POLYGON ((323306.492564711 6177798.251762123, ...     0
# 41     800.0  POLYGON ((323579.4343402477 6177424.552229371,...     0
# 42     800.0  POLYGON ((323602.2821531171 6177363.115292794,...     2
# 47     800.0  POLYGON ((323700.1757682087 6177647.243223595,...     2
# 48     800.0  POLYGON ((324055.2331559643 6177903.750400729,...     1
#
#    priority      reg_area  reg_id
# 0      None  1.156767e+06     3.0
# 1      None  1.156767e+06     3.0
# 4      None  1.156767e+06     3.0
# 5      None  1.156767e+06     3.0
# 35     None  1.156767e+06     3.0
# 36     None  1.156767e+06     3.0
# 37     None  1.156767e+06     3.0
# 38     None  1.156767e+06     3.0
# 40     None  1.156767e+06     3.0
# 41     None  1.156767e+06     3.0
# 42     None  1.156767e+06     3.0
# 47     None  1.156767e+06     3.0
# 48     None  1.156767e+06     3.0

# %% [markdown]
# # Check Poi Calculation

# %%
from code.misc import getPoiScore, adjustScore, getPOI

# %% [markdown]
# ### Check Buffer coefficients

# %%
poi_test = poi.copy()
poi_test['type'] = pd.Series(['foot']*3 + ['stepless']*2)

# %%
result = adjustScore(poi_test, settings)

# %%
assert (result['score'] == pd.Series([320.0, 640.0, 80.0, 1500.0, 1000.0])).all()

# %% [markdown]
# ## Check spatial grouping

# %%
x = getPOI(buff, poi, settings)

# %%
assert len(x)==10

# %%
x = adjustScore(x, settings)

# %%
result_score = x.groupby('office_id').agg({'score': 'sum'})
print result_score

# %%
from pandas.util.testing import isiterable

# %%
def get_pois(pois):
    '''gets two types of pois, 
    depending of "aquisition" buffer'''
    stepless_poi = pois[pois['type']=='stepless'].groupby('office_id').agg({'pid': lambda x: list(x)}).unstack()
    foot_poi = pois[pois['type']=='foot'].groupby('office_id').agg({'pid': lambda x: list(x)}).unstack()

    pois = pd.DataFrame({'stepless_poi':stepless_poi,
                 'foot_poi': foot_poi})
    pois.index = pois.index.get_level_values(1)
    return pois

# %%
pois = get_pois(x)
pois

# %%
pois

# %% [markdown]
# ## Check overal function

# %%
poi_score, pois = getPoiScore(buff, poi, settings)

# %%
poi_score

# %%
pois

# %% [markdown]
# # Check region calculations

# %% [markdown]
# ## Check spatial part

# %%
results = []
for n, g in buff.reset_index().groupby('office_id'):
    r = gp.overlay(g, reg, how='intersection')
    results.append(r)
    
my_result = gp.GeoDataFrame(pd.concat(results))[['type','geometry','disabled', 'reg_area','office_id']]

# %%
from geopandas.tools import sjoin

# %%
# %%timeit
results = []

for n, g in buff.reset_index().groupby('office_id'):
    r = sjoin(g, regs_overlayed, how='left', op='contains')
    results.append(r)
    
my_result = gp.GeoDataFrame(pd.concat(results))
# Out:
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# Warning: CRS does not match!
# 10 loops, best of 3: 116 ms per loop

# %%
my_result2 = sjoin(buff.reset_index(), regs_overlayed, how='left', op='contains')
# Out:
# Warning: CRS does not match!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-0a0d9573bd29> in <module>()
# ----> 1 my_result2 = sjoin(buff, regs_overlayed, how='left', op='contains')
#
# /Users/philippk/anaconda/lib/python2.7/site-packages/geopandas/tools/sjoin.pyc in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#      81                                left_df['geometry']
#      82                                .apply(lambda x: prepared.prep(x))[l_idx],
# ---> 83                                right_df['geometry'][r_idx])
#      84                            ]))
#      85                    )
#
# /Users/philippk/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in __call__(self, *args, **kwargs)
#    2216             vargs.extend([kwargs[_n] for _n in names])
#    2217
# -> 2218         return self._vectorize_call(func=func, args=vargs)
#    2219
#    2220     def _get_ufunc_and_otypes(self, func, args):
#
# /Users/philippk/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in _vectorize_call(self, func, args)
#    2279             _res = func()
#    2280         else:
# -> 2281             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2282
#    2283             # Convert args to object arrays first
#
# /Users/philippk/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in _get_ufunc_and_otypes(self, func, args)
#    2241             # arrays (the input values are not checked to ensure this)
#    2242             inputs = [asarray(_a).flat[0] for _a in args]
# -> 2243             outputs = func(*inputs)
#    2244
#    2245             # Performance note: profiling indicates that -- for simple
#
# /Users/philippk/anaconda/lib/python2.7/site-packages/geopandas/tools/sjoin.pyc in find_contains(a1, a2)
#      65
#      66         def find_contains(a1, a2):
# ---> 67             return a1.contains(a2)
#      68
#      69         predicate_d = {'intersects': find_intersects,
#
# AttributeError: 'float' object has no attribute 'contains'

# %%
len(my_result)
# Out:
# 55

# %%
len(my_result2)
# Out:
# 55

# %%
my_result.plot()

# %%
my_result[my_result['office_id']==3].plot()

# %%
my_result

# %%
my_result[my_result['office_id']==1].shape

# %%
my_result['disabled'] * (my_result.area / my_result['reg_area'])

# %% [markdown]
# ## Check calculations

# %%
g = getRegScore(buff, reg, settings)

# %%
g

# %% [markdown]
# ## Check Data update

# %%
buff[buff.index.get_level_values(1) != 2]

# %%
buff.loc[idx['foot',:],'geometry']

# %%
bid = 1

slctd_foot = buff.loc[idx['foot', bid], 'geometry']
slctd_step = buff.loc[idx['stepless', bid], 'geometry']
buff = buff[buff.index.get_level_values(1) != bid]

# %%
fs = buff.loc[idx['stepless', :], :].copy()
fs.loc[:, 'geometry'] = fs.loc[:, 'geometry'].intersection(slctd_foot)

# %%
fs.plot()

# %%
def get_fc(buff, slctd_step):
        fs = buff.loc[idx['stepless', :], :].copy()
        fs.loc[:, 'geometry'] = fs.loc[:, 'geometry'].intersection(slctd_step)
        fs.index = pd.MultiIndex.from_tuples([('foot_to_step', i) for _ , i in fs.index.tolist()])
        fs = fs[~fs['geometry'].is_empty]

        return pd.concat([buff, fs])

# %%
get_fc(buff, slctd_foot).plot()

# %%
def get_fc(buff, slctd_foot):
        '''adds a third type of buffer
        one where foot distance is already covered,
        but stepless is not. pois and regions here
        will add a score=difference between foot and stepless

        Args:
            buff: current buffs
            slctd_step: stepless buffer for selected office
        Returns:
            buff: buff with new buffers adder
        '''
        fs = buff.loc[idx['stepless', :], :].copy()
        
        fs.loc[:, 'geometry'] = fs.loc[:, 'geometry'].intersection(slctd_foot)
        fs.index = pd.MultiIndex.from_tuples([('foot_to_step', i) for _, i in fs.index.tolist()])
        fs = fs[~fs['geometry'].is_empty]

        return pd.concat([buff, fs]).sort_index()


def update_buff(buff, bid):
        '''update buff by removing
        and substracting
        buffers for chosen office

        Args:
            buff: buffers
            bid(int): id of chosen office
        '''
        
        slctd_foot = buff.loc[idx['foot', bid], 'geometry']
        slctd_step = buff.loc[idx['stepless', bid], 'geometry']
        buff = buff[buff.index.get_level_values(1) != bid]

        # normal reduction
        buff.loc[idx['foot', :], 'geometry'] = buff.loc[
            idx['foot', :], 'geometry'].difference(slctd_foot)
        buff.loc[idx['foot', :], 'geometry'] = buff.loc[
            idx['foot', :], 'geometry'].difference(slctd_step)
        buff.loc[idx['stepless', :], 'geometry'] = buff.loc[
            idx['stepless', :], 'geometry'].difference(slctd_step)
        
        if 'foot_to_step' in buff.index.get_level_values(0):
            buff.loc[idx['foot_to_step', :], 'geometry'] = buff.loc[
                idx['foot_to_step', :], 'geometry'].difference(slctd_step)

        buff = buff[~buff['geometry'].is_empty]
        buff2 = get_fc(buff, slctd_foot)

        return buff2

# %%
poi, buff, reg = data_preload(settings, logger)

# %%
buff2 = update_buff(buff,1)
buff2.plot()

# %%
buff2

# %%
update_buff(buff2, 2).plot()

# %% [markdown]
# ## Check Preparation

# %%
poi[poi.intersects(buff.unary_union)]

# %%
def prepare(buff, poi, reg, settings):
    '''optimize geometry for the iteration'''

    n_pois = len(poi)
    poi = poi[poi.intersects(buff.unary_union)]
    settings['logger'].info(
        'Dropped {} pois, as they are out of borders'.format(len(poi) - n_pois))

    return buff, poi, reg

# %%
buff, poi, reg = prepare(buff, poi, reg, settings)

# %% [markdown]
# # CHeck overal iteration

# %%
# ?iteration

# %%
bid, score, reg_score, foot_pois, stepless_pois = iteration(1, buff, poi, reg, settings)

# %%
stepless_pois

# %% [markdown]
# ## RUN WHOLE THING

# %%
poi, buff, reg = data_preload(settings, logger)

# %%
iterate(buff, poi, reg, 'test_results.txt', settings)
# Out:
# /Users/philippk/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:476: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ## Intersection check

# %%
buff.plot()

# %%
def if_overlaps_other(buff):
    ''''''
    z = buff_reset_index()
    overlay = gp.overlay(z, z, 'union')[['office_id', 'type']]
    return overlay.groupby('office_id').agg('count') ==1
# Out:
#             type
# office_id
# 1          False
# 2          False
# 3          False
